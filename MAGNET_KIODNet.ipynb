# %% [markdown]
# <h1><center><b> MAGNET: A Lightweight DNN and SensorFusion based Time Series Classification for Indoor Outdoor Detection</center></h1></b>

# %% [markdown]
# <h2><b>  Author:</h2></b>
#
#         Bilal Dastagir

# %% [markdown]
# ## Mount Google Colab

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive')
    dataset_Path = '/content/gdrive/MyDrive/Datasets/'
    model_Path = '/content/gdrive/MyDrive/models/'
except:
    dataset_Path = '/home/bilz/air/Datasets/'
    model_Path = '/home/bilz/air/models/'

dataset_Path_MAGNET = dataset_Path + 'magnetData.csv'
DATA_PATH = dataset_Path_MAGNET
print(DATA_PATH)
# Out:
# /home/bilz/air/Datasets/magnetData.csv

# %%
version = 1
window_size = 6
epoch_number = 100
batch_number = 64
fold_number = 6
input_features = 8
outputs_class = 2

# %% [markdown]
# <h2><b>  Importing all the necessary libraries </h2></b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import scipy.stats as stats
import time
import seaborn as sns
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, LSTM, Dense, Dropout, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import KFold
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, roc_curve, auc
warnings.filterwarnings('ignore')
#Printing the version of TensorFlow in use
print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# ## MAGNET: A Lightweight DNN and SensorFusion based Time Series Classification for Indoor Outdoor Detection .

# %% [markdown]
# <h2><b> Pre-processing of the Dataset </b></h2>

# %%
# load the original CSV file into a DataFrame
df = pd.read_csv(DATA_PATH)
print(df.head())
# Out:
#    index   state     timestamp      mag-z    mag-y    mag-x     acc-z  \
# 0      1  Indoor  1.680000e+18 -42.937500 -4.48125  6.05625  0.244359
# 1      2  Indoor  1.680000e+18 -42.937500 -4.48125  6.05625  0.229561
# 2      3  Indoor  1.680000e+18 -42.187500 -4.44375  6.45000  0.223114
# 3      4  Indoor  1.680000e+18 -42.187500 -4.44375  6.45000  0.201526
# 4      5  Indoor  1.680000e+18 -42.393753 -4.10625  6.15000  0.153779
#
#       acc-y     acc-x    gyro-z    gyro-y    gyro-x
# 0  0.034834  0.077173 -0.067957 -0.048410 -0.019700
# 1  0.008512  0.062387 -0.081395 -0.047799 -0.008705
# 2 -0.032783  0.058086 -0.087504 -0.038636 -0.000764
# 3 -0.042683  0.089896 -0.087504 -0.059405  0.002291
# 4 -0.027008  0.056276 -0.085060 -0.060627  0.001069

# %%
columns = ['index','state','timestamp','mag-z','mag-y','mag-x','acc-z','acc-y','acc-x','gyro-z','gyro-y','gyro-x']
data = pd.DataFrame(data = df, columns = columns)
print('Shape of the data:', data.shape)
# Converting the string formatted data into float
data['mag-z'] = data['mag-z'].astype('float')
data['mag-y'] = data['mag-y'].astype('float')
data['mag-x'] = data['mag-x'].astype('float')
data['acc-z'] = data['acc-z'].astype('float')
data['acc-y'] = data['acc-y'].astype('float')
data['acc-x'] = data['acc-x'].astype('float')
data['gyro-z'] = data['gyro-z'].astype('float')
data['gyro-y'] = data['gyro-y'].astype('float')
data['gyro-x'] = data['gyro-x'].astype('float')
Fs = 20 # Number of Frames
states = data['state'].value_counts().index
# Out:
# Shape of the data: (1230567, 12)

# %% [markdown]
# ### Ploting the Dataset

# %%
def plot_state(state, data):
    fig, (mx0, mx1, mx2) = plt.subplots(nrows=3, figsize=(15, 7), sharex=True)
    plot_axis(mx0, data['index'], data['mag-z'], 'Magnetometer Z-Axis')
    plot_axis(mx1, data['index'], data['mag-y'], 'Magnetometer Y-Axis')
    plot_axis(mx2, data['index'], data['mag-x'], 'Magnetometer X-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(state)
    plt.subplots_adjust(top=0.90)
    plt.show()

   

def plot_axis(mx, x, y, title):
    mx.plot(x, y, 'b')
    mx.set_title(title)
    mx.xaxis.set_visible(False)
    mx.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    mx.set_xlim([min(x), max(x)])
    mx.grid(True)

for state in states:
    data_for_plot = data[(data['state'] == state)][:Fs*10]
    plot_state(state, data_for_plot)

def plot_state(state, data):
    fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(15, 7), sharex=True)
    plot_axis(ax0, data['index'], data['acc-z'], 'Accelerometer Z-Axis')
    plot_axis(ax1, data['index'], data['acc-y'], 'Accelerometer Y-Axis')
    plot_axis(ax2, data['index'], data['acc-x'], 'Accelerometer X-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(state)
    plt.subplots_adjust(top=0.90)
    plt.show()

   

def plot_axis(ax, x, y, title):
    ax.plot(x, y, 'b')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for state in states:
    data_for_plot = data[(data['state'] == state)][:Fs*10]
    plot_state(state, data_for_plot)

def plot_state(state, data):
    fig, (gx0, gx1, gx2) = plt.subplots(nrows=3, figsize=(15, 7), sharex=True)
    plot_axis(gx0, data['index'], data['gyro-z'], 'Gyroscope Z-Axis')
    plot_axis(gx1, data['index'], data['gyro-y'], 'Gyroscope Y-Axis')
    plot_axis(gx2, data['index'], data['gyro-x'], 'Gyroscope X-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(state)
    plt.subplots_adjust(top=0.90)
    plt.show()

   

def plot_axis(mx, x, y, title):
    mx.plot(x, y, 'b')
    mx.set_title(title)
    mx.xaxis.set_visible(False)
    mx.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    mx.set_xlim([min(x), max(x)])
    mx.grid(True)

for state in states:
    data_for_plot = data[(data['state'] == state)][:Fs*10]
    plot_state(state, data_for_plot)

# %% [markdown]
# Here the MAGNET dataset has an un-equal nuber of values is each label. Hence we need to balance the dataset, otherwise their is a possibility of overfitting for certain labels or low accuracy for certain labels.

# %% [markdown]
# ###  Balancing the Dataset

# %% [markdown]
# As observed "Indoor" has the most values, whereas the label "Outdoor" has the least

# %%
df = data.drop(['index', 'timestamp'], axis = 1).copy()
df['state'].value_counts()
# Out:
# Indoor     699739
# Outdoor    530828
# Name: state, dtype: int64

# %%
# Analyzing Class Label Distribution
sns.set_style('whitegrid')
sns.set(rc = {'figure.figsize':(15,8)})
sns.countplot(x = 'state', data = df)
plt.title('Training Examples by State Type')
plt.show()

# %% [markdown]
# Since "Outdoor" has the least quantity of data, we have taken it as a reference for balancing

# %%
Outdoor = df[df['state'] == 'Outdoor'].copy()
Indoor = df[df['state'] == 'Indoor'].head(530828).copy()

# %%
balanced_data = pd.DataFrame()
balanced_data = balanced_data.append([Outdoor, Indoor])
balanced_data.shape
# Out:
# (1061656, 10)

# %%
# Displaying the balanced data
print('State Count:',balanced_data['state'].value_counts())
# Out:
# State Count: Outdoor    530828
# Indoor     530828
# Name: state, dtype: int64

# %%
# Analyzing Class Label Distribution
sns.set_style('whitegrid')
sns.set(rc = {'figure.figsize':(15,8)})
sns.countplot(x = 'state', data = balanced_data)
plt.title('Training Examples by State Type')
plt.show()

# %%
# Encoding the Data with suitable labels
label = LabelEncoder()
balanced_data['label'] = label.fit_transform(balanced_data['state'])
balanced_data.head()
# Out:
#           state      mag-z    mag-y    mag-x     acc-z     acc-y     acc-x  \
# 615056  Outdoor -29.850000  2.30625  6.76875 -0.496039 -0.642663  0.620323
# 615057  Outdoor -29.850000  2.30625  6.76875 -0.404016 -0.692411  0.727258
# 615058  Outdoor -29.812502  2.17500  6.90000 -0.228154 -0.713446  0.695428
# 615059  Outdoor -29.812502  2.17500  6.90000  0.000651 -0.739677  0.664212
# 615060  Outdoor -29.812502  2.23125  6.75000  0.199010 -0.814597  0.567077
#
#           gyro-z    gyro-y    gyro-x  label
# 615056  0.021761  0.484020  0.201809      1
# 615057 -0.010003  0.382619  0.202420      1
# 615058 -0.049097  0.285495  0.200587      1
# 615059 -0.093689  0.197533  0.209139      1
# 615060 -0.127896  0.129729  0.231129      1

# %% [markdown]
# ### Standardizing the Dataset

# %%
X = balanced_data[['mag-z','mag-y','mag-x','acc-z','acc-y','acc-x','gyro-z','gyro-y','gyro-x']]
y = balanced_data['label']

scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ['mag-z','mag-y','mag-x','acc-z','acc-y','acc-x','gyro-z','gyro-y','gyro-x'])
scaled_X['label'] = y.values

scaled_X
# Out:
#             mag-z     mag-y     mag-x     acc-z     acc-y     acc-x    gyro-z  \
# 0       -0.869137  0.635887  0.405753 -0.517265 -0.712834  0.707775  0.045720
# 1       -0.869137  0.635887  0.405753 -0.430168 -0.777701  0.829877 -0.025594
# 2       -0.867541  0.629642  0.411120 -0.263720 -0.805129  0.793532 -0.113364
# 3       -0.867541  0.629642  0.411120 -0.047163 -0.839332  0.757889 -0.213478
# 4       -0.867541  0.632318  0.404986  0.140579 -0.937023  0.646977 -0.290277
# ...           ...       ...       ...       ...       ...       ...       ...
# 1061651 -1.633647  0.775973 -0.551260  0.249971 -0.435865 -2.166530 -1.353293
# 1061652 -1.644820  0.776865 -0.550493  0.302092 -0.525969 -2.287590 -1.350550
# 1061653 -1.644820  0.776865 -0.550493  0.339360 -0.608265 -2.327967 -1.372493
# 1061654 -1.653598  0.783111 -0.554328  0.312230 -0.676848 -2.318422 -1.384836
# 1061655 -1.653598  0.783111 -0.554328  0.268509 -0.772608 -2.275717 -1.408150
#
#            gyro-y    gyro-x  label
# 0        1.216997  0.499499      1
# 1        0.960250  0.501028      1
# 2        0.714330  0.496441      1
# 3        0.491610  0.517849      1
# 4        0.319930  0.572900      1
# ...           ...       ...    ...
# 1061651 -0.012217 -0.046615      0
# 1061652 -0.123578  0.019141      0
# 1061653 -0.221018  0.101717      0
# 1061654 -0.346298  0.201115      0
# 1061655 -0.499418  0.315804      0
#
# [1061656 rows x 10 columns]

# %%
Fs = 20
frame_size = Fs*4 # 80
hop_size = Fs*2 # 40

def get_frames(df, frame_size, hop_size):

    N_FEATURES = 9

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, hop_size):
        mag_z = df['mag-z'].values[i: i + frame_size]
        mag_y = df['mag-y'].values[i: i + frame_size]
        mag_x = df['mag-x'].values[i: i + frame_size]
        acc_z = df['acc-z'].values[i: i + frame_size]
        acc_y = df['acc-y'].values[i: i + frame_size]
        acc_x = df['acc-x'].values[i: i + frame_size]
        gyro_z = df['gyro-z'].values[i: i + frame_size]
        gyro_y = df['gyro-y'].values[i: i + frame_size]
        gyro_x = df['gyro-x'].values[i: i + frame_size]
        
        # Retrieve the most often used label in this segment
        label = stats.mode(df['label'][i: i + frame_size])[0][0]
        frames.append([mag_z, mag_y, mag_x, acc_z, acc_y, acc_x, gyro_z, gyro_y, gyro_x])
        labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

# %%
scaled_X = scaled_X.replace([np.inf, -np.inf], np.nan)
scaled_X = scaled_X.dropna()
scaled_X = scaled_X.reset_index()
X, y = get_frames(scaled_X, frame_size, hop_size)
X.shape, y.shape
# Out:
# ((26540, 80, 9), (26540,))

# %%
scaled_X.shape
# Out:
# (1061656, 11)

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# Creating the K-fold cross-validation iterator
kfold = StratifiedKFold(n_splits=fold_number, shuffle=True, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# Shape of X: (26540, 80, 9)
# Shape of y: (26540,)
# ((21232, 80, 9), (5308, 80, 9), (21232,), (5308,))

# %%
#import numpy as npt
#npt.savetxt('X_test.csv', X_test.reshape(X_test.shape[0], -1), delimiter=',')
#npt.savetxt('y_test.csv', y_test, delimiter=',')

# %%
from keras.layers import Input


n_timesteps = X_train.shape[1]
n_features = X_train.shape[2]
n_outputs = 2#y_train.shape[1]

input_shape=(n_timesteps,n_features)
inputs = Input(shape=input_shape)

print("input_shape = ",input_shape)
print("n_outputs = ",n_outputs)
# Out:
# input_shape =  (80, 9)
# n_outputs =  2

# %% [markdown]
# <h2><b>Propose Model</h2></b>

# %%
# Define the CNN-LSTM model with 2 parallel 1D CNN branches
def parallel_CNN_LSTM(input_shape, n_outputs):
    inputs = Input(shape=input_shape)

    # First 1D CNN branch
    x1 = Conv1D(64, kernel_size=3, activation='relu')(inputs)
    x1 = MaxPooling1D(2)(x1)
    x1 = LSTM(64)(x1)

    # Second 1D CNN branch
    x2 = Conv1D(64, kernel_size=5, activation='relu')(inputs)
    x2 = MaxPooling1D(2)(x2)
    x2 = LSTM(64)(x2)

    # Concatenate the outputs from both branches
    x = concatenate([x1, x2])

    x = Dropout(0.2)(x)
    outputs = Dense(n_outputs, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Training

# %%
# Function to train the model using K-fold cross-validation
def trainingModel(model_path, X, y, fold_number=6, epoch_number=100, batch_number=64):
    # Create KFold instance
    kfold = KFold(n_splits=fold_number, shuffle=True)

    # Create empty lists to store the fold models and evaluation results
    fold_models = []
    fold_test_acc = []
    fold_test_f1 = []
    fold_prediction_times = []
    fold_training_times = []

    # Looping over the folds
    for fold, (train_index, val_index) in enumerate(kfold.split(X, y)):
        print(f"Fold {fold+1}:")

        # Get the train and validation sets for this fold
        X_train_fold, X_val_fold = X[train_index], X[val_index]
        y_train_fold, y_val_fold = y[train_index], y[val_index]

        # Define the filepath for the saved model specific to this fold
        filepath = model_path + f"bd_MAGNet_V{version}_W_{window_size}_F_{fold+1}.h5"

        # Define early stopping based on validation loss
        early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

        # Define a checkpoint to monitor the validation accuracy and save the best model
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

        input_shape = X_train[0].shape
        # Create the CNN-LSTM model with parallel 1D CNNs
        model = parallel_CNN_LSTM(input_shape, outputs_class)

        # Compile the model
        optimizer = Adam(learning_rate=0.001)
        model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

        # Start the training time measurement
        start_time = time.time()

        # Train the model with the checkpoint callback for this fold
        history = model.fit(X_train_fold, y_train_fold, epochs=epoch_number, batch_size=batch_number,
                            validation_data=(X_val_fold, y_val_fold), callbacks=[checkpoint, early_stop], verbose=1)

        # End the training time measurement
        end_time = time.time()
        training_time = end_time - start_time

        # Save the fold model to the list
        fold_models.append(model)

        # Evaluate the model on the test set
        test_pred = model.predict(X_test)
        test_pred_labels = np.argmax(test_pred, axis=1)

        if len(y_test.shape) > 1 and y_test.shape[1] > 1:
            test_true_labels = np.argmax(y_test, axis=1)
        else:
            test_true_labels = y_test

        test_acc = accuracy_score(test_true_labels, test_pred_labels)
        test_f1 = f1_score(test_true_labels, test_pred_labels, average='weighted')

        # Calculate the prediction time
        start_time = time.time()
        model.predict(X_test[:1])
        end_time = time.time()
        prediction_time = (end_time - start_time) * 1000  # Convert to milliseconds

        # Save the evaluation results and times to the lists
        fold_test_acc.append(test_acc)
        fold_test_f1.append(test_f1)
        fold_prediction_times.append(prediction_time)
        fold_training_times.append(training_time)

    # Calculate mean and median times for prediction and training
    mean_prediction_time = np.mean(fold_prediction_times) / 1000  # Convert back to seconds
    median_prediction_time = np.median(fold_prediction_times) / 1000  # Convert back to seconds
    mean_training_time = np.mean(fold_training_times)
    median_training_time = np.median(fold_training_times)

    # Calculate the total number of parameters
    total_params = model.count_params()

    # Convert the total number of parameters to kilobytes (KB)
    total_params_kb = total_params / 1024  # 1 KB = 1024 bytes

    # Convert the total number of parameters to megabytes (MB)
    total_memory_mb = total_params * 4 / (1024 * 1024)  # Assuming float32 precision (4 bytes per parameter)

    # Save the averaged model
    averaged_model = fold_models[0]
    averaged_weights = averaged_model.get_weights()

    n_splits = fold_number
    # Loop over the layers of the models and average the weights
    for layer in range(len(averaged_weights)):
        for fold in range(1, n_splits):
            averaged_weights[layer] += fold_models[fold].get_weights()[layer]

        averaged_weights[layer] /= n_splits

    # Set the averaged weights to the averaged model
    averaged_model.set_weights(averaged_weights)
    averaged_filepath = model_path + f"bd_MAGNet_V{version}_W_{window_size}.h5"
    averaged_model.save(averaged_filepath)

    return averaged_model, fold_test_acc, fold_test_f1, mean_prediction_time, median_prediction_time, mean_training_time, median_training_time, total_memory_mb, total_params_kb

# %%
# Train the model and get the required outputs
trained_model, test_acc, test_f1, mean_prediction_time, median_prediction_time, mean_training_time, median_training_time, total_memory_mb, total_params_kb = trainingModel(model_Path, X_train, y_train)
# Out:
# Fold 1:
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8886
# Epoch 1: val_accuracy improved from -inf to 0.91551, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 6s 17ms/step - loss: 0.2862 - accuracy: 0.8886 - val_loss: 0.2274 - val_accuracy: 0.9155
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9324
# Epoch 2: val_accuracy improved from 0.91551 to 0.94123, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.2030 - accuracy: 0.9324 - val_loss: 0.1780 - val_accuracy: 0.9412
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9387
# Epoch 3: val_accuracy did not improve from 0.94123
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1864 - accuracy: 0.9387 - val_loss: 0.1895 - val_accuracy: 0.9373
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9423
# Epoch 4: val_accuracy improved from 0.94123 to 0.94462, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1743 - accuracy: 0.9423 - val_loss: 0.1660 - val_accuracy: 0.9446
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9443
# Epoch 5: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1674 - accuracy: 0.9443 - val_loss: 0.1701 - val_accuracy: 0.9438
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9451
# Epoch 6: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1645 - accuracy: 0.9451 - val_loss: 0.1961 - val_accuracy: 0.9378
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9459
# Epoch 7: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1636 - accuracy: 0.9459 - val_loss: 0.1651 - val_accuracy: 0.9401
# Epoch 8/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9463
# Epoch 8: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1572 - accuracy: 0.9463 - val_loss: 0.1605 - val_accuracy: 0.9446
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9463
# Epoch 9: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1582 - accuracy: 0.9463 - val_loss: 0.1695 - val_accuracy: 0.9443
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9504
# Epoch 10: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1497 - accuracy: 0.9504 - val_loss: 0.1667 - val_accuracy: 0.9426
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9483
# Epoch 11: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1519 - accuracy: 0.9483 - val_loss: 0.1585 - val_accuracy: 0.9432
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9495
# Epoch 12: val_accuracy improved from 0.94462 to 0.94518, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1518 - accuracy: 0.9495 - val_loss: 0.1550 - val_accuracy: 0.9452
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9508
# Epoch 13: val_accuracy did not improve from 0.94518
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1442 - accuracy: 0.9508 - val_loss: 0.1706 - val_accuracy: 0.9392
# Epoch 14/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9500
# Epoch 14: val_accuracy did not improve from 0.94518
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1427 - accuracy: 0.9500 - val_loss: 0.1545 - val_accuracy: 0.9435
# Epoch 15/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9518
# Epoch 15: val_accuracy improved from 0.94518 to 0.94857, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1403 - accuracy: 0.9518 - val_loss: 0.1539 - val_accuracy: 0.9486
# Epoch 16/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9516
# Epoch 16: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1380 - accuracy: 0.9516 - val_loss: 0.1475 - val_accuracy: 0.9477
# Epoch 17/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9540
# Epoch 17: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1326 - accuracy: 0.9540 - val_loss: 0.1562 - val_accuracy: 0.9477
# Epoch 18/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9517
# Epoch 18: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1356 - accuracy: 0.9517 - val_loss: 0.1518 - val_accuracy: 0.9477
# Epoch 19/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9547
# Epoch 19: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1310 - accuracy: 0.9547 - val_loss: 0.1496 - val_accuracy: 0.9483
# Epoch 20/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9563
# Epoch 20: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1268 - accuracy: 0.9563 - val_loss: 0.1561 - val_accuracy: 0.9446
# Epoch 21/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9557
# Epoch 21: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1254 - accuracy: 0.9557 - val_loss: 0.1528 - val_accuracy: 0.9424
# Epoch 22/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9558
# Epoch 22: val_accuracy did not improve from 0.94857
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1220 - accuracy: 0.9558 - val_loss: 0.1498 - val_accuracy: 0.9466
# Epoch 23/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9573
# Epoch 23: val_accuracy improved from 0.94857 to 0.95055, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1188 - accuracy: 0.9573 - val_loss: 0.1393 - val_accuracy: 0.9506
# Epoch 24/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9572
# Epoch 24: val_accuracy did not improve from 0.95055
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1165 - accuracy: 0.9572 - val_loss: 0.1463 - val_accuracy: 0.9494
# Epoch 25/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9598
# Epoch 25: val_accuracy did not improve from 0.95055
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1131 - accuracy: 0.9598 - val_loss: 0.1544 - val_accuracy: 0.9421
# Epoch 26/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9593
# Epoch 26: val_accuracy did not improve from 0.95055
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1114 - accuracy: 0.9593 - val_loss: 0.1532 - val_accuracy: 0.9489
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9582
# Epoch 27: val_accuracy improved from 0.95055 to 0.95366, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1106 - accuracy: 0.9582 - val_loss: 0.1470 - val_accuracy: 0.9537
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9619
# Epoch 28: val_accuracy did not improve from 0.95366
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1031 - accuracy: 0.9619 - val_loss: 0.1586 - val_accuracy: 0.9491
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9631
# Epoch 29: val_accuracy did not improve from 0.95366
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0977 - accuracy: 0.9631 - val_loss: 0.1503 - val_accuracy: 0.9483
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9630
# Epoch 30: val_accuracy improved from 0.95366 to 0.95422, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_1.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0972 - accuracy: 0.9630 - val_loss: 0.1394 - val_accuracy: 0.9542
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9646
# Epoch 31: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0963 - accuracy: 0.9646 - val_loss: 0.1538 - val_accuracy: 0.9486
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0980 - accuracy: 0.9626
# Epoch 32: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0980 - accuracy: 0.9626 - val_loss: 0.1476 - val_accuracy: 0.9500
# Epoch 33/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9645
# Epoch 33: val_accuracy did not improve from 0.95422
# Restoring model weights from the end of the best epoch: 23.
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0928 - accuracy: 0.9645 - val_loss: 0.1563 - val_accuracy: 0.9514
# Epoch 33: early stopping
# 166/166 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# Fold 2:
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.8900
# Epoch 1: val_accuracy improved from -inf to 0.93162, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 6s 17ms/step - loss: 0.2879 - accuracy: 0.8900 - val_loss: 0.1949 - val_accuracy: 0.9316
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9355
# Epoch 2: val_accuracy improved from 0.93162 to 0.94207, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1932 - accuracy: 0.9355 - val_loss: 0.1756 - val_accuracy: 0.9421
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9357
# Epoch 3: val_accuracy did not improve from 0.94207
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1889 - accuracy: 0.9357 - val_loss: 0.2018 - val_accuracy: 0.9268
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9418
# Epoch 4: val_accuracy did not improve from 0.94207
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1723 - accuracy: 0.9418 - val_loss: 0.1778 - val_accuracy: 0.9384
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9439
# Epoch 5: val_accuracy did not improve from 0.94207
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1649 - accuracy: 0.9439 - val_loss: 0.1733 - val_accuracy: 0.9384
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9444
# Epoch 6: val_accuracy did not improve from 0.94207
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1606 - accuracy: 0.9444 - val_loss: 0.1707 - val_accuracy: 0.9401
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9449
# Epoch 7: val_accuracy improved from 0.94207 to 0.94349, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1621 - accuracy: 0.9449 - val_loss: 0.1587 - val_accuracy: 0.9435
# Epoch 8/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9473
# Epoch 8: val_accuracy did not improve from 0.94349
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1528 - accuracy: 0.9473 - val_loss: 0.1731 - val_accuracy: 0.9426
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9482
# Epoch 9: val_accuracy improved from 0.94349 to 0.94433, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1517 - accuracy: 0.9482 - val_loss: 0.1592 - val_accuracy: 0.9443
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9491
# Epoch 10: val_accuracy did not improve from 0.94433
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1473 - accuracy: 0.9491 - val_loss: 0.1629 - val_accuracy: 0.9409
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9498
# Epoch 11: val_accuracy did not improve from 0.94433
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1474 - accuracy: 0.9498 - val_loss: 0.1596 - val_accuracy: 0.9441
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9503
# Epoch 12: val_accuracy did not improve from 0.94433
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1404 - accuracy: 0.9503 - val_loss: 0.1631 - val_accuracy: 0.9421
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9489
# Epoch 13: val_accuracy did not improve from 0.94433
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1468 - accuracy: 0.9489 - val_loss: 0.1721 - val_accuracy: 0.9384
# Epoch 14/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9529
# Epoch 14: val_accuracy improved from 0.94433 to 0.94462, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1349 - accuracy: 0.9529 - val_loss: 0.1494 - val_accuracy: 0.9446
# Epoch 15/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9541
# Epoch 15: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1306 - accuracy: 0.9541 - val_loss: 0.1570 - val_accuracy: 0.9435
# Epoch 16/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9536
# Epoch 16: val_accuracy did not improve from 0.94462
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1332 - accuracy: 0.9536 - val_loss: 0.1554 - val_accuracy: 0.9443
# Epoch 17/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9559
# Epoch 17: val_accuracy improved from 0.94462 to 0.94688, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1271 - accuracy: 0.9559 - val_loss: 0.1567 - val_accuracy: 0.9469
# Epoch 18/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9570
# Epoch 18: val_accuracy did not improve from 0.94688
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1246 - accuracy: 0.9570 - val_loss: 0.1573 - val_accuracy: 0.9429
# Epoch 19/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9565
# Epoch 19: val_accuracy did not improve from 0.94688
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1209 - accuracy: 0.9565 - val_loss: 0.1475 - val_accuracy: 0.9463
# Epoch 20/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9585
# Epoch 20: val_accuracy did not improve from 0.94688
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1135 - accuracy: 0.9585 - val_loss: 0.1512 - val_accuracy: 0.9455
# Epoch 21/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9596
# Epoch 21: val_accuracy did not improve from 0.94688
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1118 - accuracy: 0.9596 - val_loss: 0.1481 - val_accuracy: 0.9443
# Epoch 22/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9581
# Epoch 22: val_accuracy improved from 0.94688 to 0.94942, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1121 - accuracy: 0.9581 - val_loss: 0.1436 - val_accuracy: 0.9494
# Epoch 23/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9616
# Epoch 23: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1052 - accuracy: 0.9616 - val_loss: 0.1531 - val_accuracy: 0.9469
# Epoch 24/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9616
# Epoch 24: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1013 - accuracy: 0.9616 - val_loss: 0.1723 - val_accuracy: 0.9438
# Epoch 25/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9628
# Epoch 25: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1005 - accuracy: 0.9628 - val_loss: 0.1498 - val_accuracy: 0.9474
# Epoch 26/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9645
# Epoch 26: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0949 - accuracy: 0.9645 - val_loss: 0.1615 - val_accuracy: 0.9489
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9661
# Epoch 27: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0926 - accuracy: 0.9661 - val_loss: 0.1524 - val_accuracy: 0.9455
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9670
# Epoch 28: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0869 - accuracy: 0.9670 - val_loss: 0.1546 - val_accuracy: 0.9449
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9713
# Epoch 29: val_accuracy did not improve from 0.94942
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0808 - accuracy: 0.9713 - val_loss: 0.1641 - val_accuracy: 0.9494
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9706
# Epoch 30: val_accuracy improved from 0.94942 to 0.95196, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_2.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0779 - accuracy: 0.9706 - val_loss: 0.1631 - val_accuracy: 0.9520
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9709
# Epoch 31: val_accuracy did not improve from 0.95196
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0763 - accuracy: 0.9709 - val_loss: 0.1522 - val_accuracy: 0.9412
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9663
# Epoch 32: val_accuracy did not improve from 0.95196
# Restoring model weights from the end of the best epoch: 22.
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0921 - accuracy: 0.9663 - val_loss: 0.1573 - val_accuracy: 0.9441
# Epoch 32: early stopping
# 166/166 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# Fold 3:
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.8794
# Epoch 1: val_accuracy improved from -inf to 0.92908, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 7s 18ms/step - loss: 0.3025 - accuracy: 0.8794 - val_loss: 0.2129 - val_accuracy: 0.9291
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9362
# Epoch 2: val_accuracy improved from 0.92908 to 0.93897, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1996 - accuracy: 0.9362 - val_loss: 0.1872 - val_accuracy: 0.9390
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9358
# Epoch 3: val_accuracy improved from 0.93897 to 0.94066, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1956 - accuracy: 0.9358 - val_loss: 0.1857 - val_accuracy: 0.9407
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9437
# Epoch 4: val_accuracy did not improve from 0.94066
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1740 - accuracy: 0.9437 - val_loss: 0.1807 - val_accuracy: 0.9376
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9437
# Epoch 5: val_accuracy improved from 0.94066 to 0.94320, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1703 - accuracy: 0.9437 - val_loss: 0.1735 - val_accuracy: 0.9432
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.9461
# Epoch 6: val_accuracy did not improve from 0.94320
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1653 - accuracy: 0.9461 - val_loss: 0.1864 - val_accuracy: 0.9376
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9476
# Epoch 7: val_accuracy improved from 0.94320 to 0.94575, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1596 - accuracy: 0.9476 - val_loss: 0.1672 - val_accuracy: 0.9457
# Epoch 8/100
# 276/277 [============================>.] - ETA: 0s - loss: 0.1618 - accuracy: 0.9462
# Epoch 8: val_accuracy did not improve from 0.94575
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1618 - accuracy: 0.9461 - val_loss: 0.1721 - val_accuracy: 0.9412
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9481
# Epoch 9: val_accuracy did not improve from 0.94575
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1553 - accuracy: 0.9481 - val_loss: 0.1600 - val_accuracy: 0.9457
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9485
# Epoch 10: val_accuracy did not improve from 0.94575
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1525 - accuracy: 0.9485 - val_loss: 0.1740 - val_accuracy: 0.9387
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9485
# Epoch 11: val_accuracy improved from 0.94575 to 0.94744, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1526 - accuracy: 0.9485 - val_loss: 0.1556 - val_accuracy: 0.9474
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9498
# Epoch 12: val_accuracy did not improve from 0.94744
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1503 - accuracy: 0.9498 - val_loss: 0.1633 - val_accuracy: 0.9415
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9516
# Epoch 13: val_accuracy improved from 0.94744 to 0.94773, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1444 - accuracy: 0.9516 - val_loss: 0.1502 - val_accuracy: 0.9477
# Epoch 14/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9499
# Epoch 14: val_accuracy did not improve from 0.94773
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1445 - accuracy: 0.9499 - val_loss: 0.1631 - val_accuracy: 0.9407
# Epoch 15/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9524
# Epoch 15: val_accuracy did not improve from 0.94773
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1377 - accuracy: 0.9524 - val_loss: 0.1747 - val_accuracy: 0.9376
# Epoch 16/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9523
# Epoch 16: val_accuracy did not improve from 0.94773
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1368 - accuracy: 0.9523 - val_loss: 0.1771 - val_accuracy: 0.9432
# Epoch 17/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9521
# Epoch 17: val_accuracy improved from 0.94773 to 0.95027, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1375 - accuracy: 0.9521 - val_loss: 0.1465 - val_accuracy: 0.9503
# Epoch 18/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9541
# Epoch 18: val_accuracy did not improve from 0.95027
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1307 - accuracy: 0.9541 - val_loss: 0.1557 - val_accuracy: 0.9494
# Epoch 19/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9534
# Epoch 19: val_accuracy improved from 0.95027 to 0.95112, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1279 - accuracy: 0.9534 - val_loss: 0.1388 - val_accuracy: 0.9511
# Epoch 20/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9563
# Epoch 20: val_accuracy improved from 0.95112 to 0.95168, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1269 - accuracy: 0.9563 - val_loss: 0.1421 - val_accuracy: 0.9517
# Epoch 21/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9567
# Epoch 21: val_accuracy did not improve from 0.95168
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1230 - accuracy: 0.9567 - val_loss: 0.1471 - val_accuracy: 0.9503
# Epoch 22/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9576
# Epoch 22: val_accuracy did not improve from 0.95168
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1209 - accuracy: 0.9576 - val_loss: 0.1534 - val_accuracy: 0.9457
# Epoch 23/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9590
# Epoch 23: val_accuracy did not improve from 0.95168
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1194 - accuracy: 0.9590 - val_loss: 0.1465 - val_accuracy: 0.9477
# Epoch 24/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9585
# Epoch 24: val_accuracy did not improve from 0.95168
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1158 - accuracy: 0.9585 - val_loss: 0.1435 - val_accuracy: 0.9517
# Epoch 25/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9594
# Epoch 25: val_accuracy improved from 0.95168 to 0.95422, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_3.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1118 - accuracy: 0.9594 - val_loss: 0.1386 - val_accuracy: 0.9542
# Epoch 26/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9605
# Epoch 26: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1085 - accuracy: 0.9605 - val_loss: 0.1685 - val_accuracy: 0.9426
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9617
# Epoch 27: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1090 - accuracy: 0.9617 - val_loss: 0.1618 - val_accuracy: 0.9469
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9635
# Epoch 28: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1037 - accuracy: 0.9635 - val_loss: 0.1392 - val_accuracy: 0.9494
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9631
# Epoch 29: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1031 - accuracy: 0.9631 - val_loss: 0.1476 - val_accuracy: 0.9531
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9639
# Epoch 30: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0999 - accuracy: 0.9639 - val_loss: 0.1334 - val_accuracy: 0.9534
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9663
# Epoch 31: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0948 - accuracy: 0.9663 - val_loss: 0.1409 - val_accuracy: 0.9517
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9661
# Epoch 32: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0943 - accuracy: 0.9661 - val_loss: 0.1522 - val_accuracy: 0.9474
# Epoch 33/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9667
# Epoch 33: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0928 - accuracy: 0.9667 - val_loss: 0.1403 - val_accuracy: 0.9472
# Epoch 34/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9659
# Epoch 34: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0909 - accuracy: 0.9659 - val_loss: 0.1387 - val_accuracy: 0.9522
# Epoch 35/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9691
# Epoch 35: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0866 - accuracy: 0.9691 - val_loss: 0.1489 - val_accuracy: 0.9539
# Epoch 36/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9677
# Epoch 36: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0875 - accuracy: 0.9677 - val_loss: 0.1493 - val_accuracy: 0.9449
# Epoch 37/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9715
# Epoch 37: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0782 - accuracy: 0.9715 - val_loss: 0.1506 - val_accuracy: 0.9424
# Epoch 38/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9704
# Epoch 38: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0787 - accuracy: 0.9704 - val_loss: 0.1489 - val_accuracy: 0.9539
# Epoch 39/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9713
# Epoch 39: val_accuracy did not improve from 0.95422
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0752 - accuracy: 0.9713 - val_loss: 0.1588 - val_accuracy: 0.9486
# Epoch 40/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9744
# Epoch 40: val_accuracy did not improve from 0.95422
# Restoring model weights from the end of the best epoch: 30.
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0693 - accuracy: 0.9744 - val_loss: 0.1596 - val_accuracy: 0.9506
# Epoch 40: early stopping
# 166/166 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# Fold 4:
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.8735
# Epoch 1: val_accuracy improved from -inf to 0.92484, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 6s 18ms/step - loss: 0.3181 - accuracy: 0.8735 - val_loss: 0.2148 - val_accuracy: 0.9248
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9334
# Epoch 2: val_accuracy improved from 0.92484 to 0.93868, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.2016 - accuracy: 0.9334 - val_loss: 0.1894 - val_accuracy: 0.9387
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9418
# Epoch 3: val_accuracy improved from 0.93868 to 0.94320, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1811 - accuracy: 0.9418 - val_loss: 0.1738 - val_accuracy: 0.9432
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9412
# Epoch 4: val_accuracy did not improve from 0.94320
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1794 - accuracy: 0.9412 - val_loss: 0.1709 - val_accuracy: 0.9415
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9439
# Epoch 5: val_accuracy did not improve from 0.94320
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1724 - accuracy: 0.9439 - val_loss: 0.1644 - val_accuracy: 0.9426
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9451
# Epoch 6: val_accuracy did not improve from 0.94320
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1634 - accuracy: 0.9451 - val_loss: 0.1633 - val_accuracy: 0.9426
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9446
# Epoch 7: val_accuracy improved from 0.94320 to 0.94433, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1673 - accuracy: 0.9446 - val_loss: 0.1650 - val_accuracy: 0.9443
# Epoch 8/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9465
# Epoch 8: val_accuracy did not improve from 0.94433
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1615 - accuracy: 0.9465 - val_loss: 0.1635 - val_accuracy: 0.9435
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9474
# Epoch 9: val_accuracy did not improve from 0.94433
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1618 - accuracy: 0.9474 - val_loss: 0.1668 - val_accuracy: 0.9429
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9495
# Epoch 10: val_accuracy improved from 0.94433 to 0.94660, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 17ms/step - loss: 0.1545 - accuracy: 0.9495 - val_loss: 0.1605 - val_accuracy: 0.9466
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.9485
# Epoch 11: val_accuracy did not improve from 0.94660
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1549 - accuracy: 0.9485 - val_loss: 0.1590 - val_accuracy: 0.9441
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 0.9488
# Epoch 12: val_accuracy did not improve from 0.94660
# 277/277 [==============================] - 5s 17ms/step - loss: 0.1515 - accuracy: 0.9488 - val_loss: 0.1651 - val_accuracy: 0.9432
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9492
# Epoch 13: val_accuracy did not improve from 0.94660
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1491 - accuracy: 0.9492 - val_loss: 0.1623 - val_accuracy: 0.9457
# Epoch 14/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9498
# Epoch 14: val_accuracy did not improve from 0.94660
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1478 - accuracy: 0.9498 - val_loss: 0.1628 - val_accuracy: 0.9460
# Epoch 15/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9501
# Epoch 15: val_accuracy improved from 0.94660 to 0.94716, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1454 - accuracy: 0.9501 - val_loss: 0.1555 - val_accuracy: 0.9472
# Epoch 16/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9501
# Epoch 16: val_accuracy did not improve from 0.94716
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1456 - accuracy: 0.9501 - val_loss: 0.1785 - val_accuracy: 0.9390
# Epoch 17/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9522
# Epoch 17: val_accuracy improved from 0.94716 to 0.94970, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1380 - accuracy: 0.9522 - val_loss: 0.1476 - val_accuracy: 0.9497
# Epoch 18/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9510
# Epoch 18: val_accuracy did not improve from 0.94970
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1402 - accuracy: 0.9510 - val_loss: 0.1468 - val_accuracy: 0.9486
# Epoch 19/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9528
# Epoch 19: val_accuracy did not improve from 0.94970
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1359 - accuracy: 0.9528 - val_loss: 0.1457 - val_accuracy: 0.9494
# Epoch 20/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9518
# Epoch 20: val_accuracy did not improve from 0.94970
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1404 - accuracy: 0.9518 - val_loss: 0.1471 - val_accuracy: 0.9472
# Epoch 21/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9542
# Epoch 21: val_accuracy did not improve from 0.94970
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1326 - accuracy: 0.9542 - val_loss: 0.1507 - val_accuracy: 0.9480
# Epoch 22/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9547
# Epoch 22: val_accuracy improved from 0.94970 to 0.95225, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1327 - accuracy: 0.9547 - val_loss: 0.1397 - val_accuracy: 0.9522
# Epoch 23/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9555
# Epoch 23: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1255 - accuracy: 0.9555 - val_loss: 0.1518 - val_accuracy: 0.9497
# Epoch 24/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9557
# Epoch 24: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1235 - accuracy: 0.9557 - val_loss: 0.1422 - val_accuracy: 0.9522
# Epoch 25/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9546
# Epoch 25: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1264 - accuracy: 0.9546 - val_loss: 0.1424 - val_accuracy: 0.9517
# Epoch 26/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9561
# Epoch 26: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1249 - accuracy: 0.9561 - val_loss: 0.1497 - val_accuracy: 0.9500
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9587
# Epoch 27: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1197 - accuracy: 0.9587 - val_loss: 0.1428 - val_accuracy: 0.9503
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9584
# Epoch 28: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1160 - accuracy: 0.9584 - val_loss: 0.1473 - val_accuracy: 0.9480
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9594
# Epoch 29: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1148 - accuracy: 0.9594 - val_loss: 0.1470 - val_accuracy: 0.9494
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9599
# Epoch 30: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1121 - accuracy: 0.9599 - val_loss: 0.1392 - val_accuracy: 0.9520
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9615
# Epoch 31: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1067 - accuracy: 0.9615 - val_loss: 0.1449 - val_accuracy: 0.9517
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9621
# Epoch 32: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1057 - accuracy: 0.9621 - val_loss: 0.1472 - val_accuracy: 0.9506
# Epoch 33/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9609
# Epoch 33: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1071 - accuracy: 0.9609 - val_loss: 0.1417 - val_accuracy: 0.9514
# Epoch 34/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9623
# Epoch 34: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1044 - accuracy: 0.9623 - val_loss: 0.1635 - val_accuracy: 0.9460
# Epoch 35/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9651
# Epoch 35: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0947 - accuracy: 0.9651 - val_loss: 0.1447 - val_accuracy: 0.9508
# Epoch 36/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9656
# Epoch 36: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0929 - accuracy: 0.9656 - val_loss: 0.1435 - val_accuracy: 0.9522
# Epoch 37/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9677
# Epoch 37: val_accuracy did not improve from 0.95225
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0881 - accuracy: 0.9677 - val_loss: 0.1488 - val_accuracy: 0.9474
# Epoch 38/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9669
# Epoch 38: val_accuracy improved from 0.95225 to 0.95309, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_4.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0908 - accuracy: 0.9669 - val_loss: 0.1430 - val_accuracy: 0.9531
# Epoch 39/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9697
# Epoch 39: val_accuracy did not improve from 0.95309
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0825 - accuracy: 0.9697 - val_loss: 0.1520 - val_accuracy: 0.9494
# Epoch 40/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9709
# Epoch 40: val_accuracy did not improve from 0.95309
# Restoring model weights from the end of the best epoch: 30.
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0789 - accuracy: 0.9709 - val_loss: 0.1557 - val_accuracy: 0.9520
# Epoch 40: early stopping
# 166/166 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# Fold 5:
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2993 - accuracy: 0.8854
# Epoch 1: val_accuracy improved from -inf to 0.92651, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 7s 18ms/step - loss: 0.2993 - accuracy: 0.8854 - val_loss: 0.2169 - val_accuracy: 0.9265
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9343
# Epoch 2: val_accuracy improved from 0.92651 to 0.93810, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.2006 - accuracy: 0.9343 - val_loss: 0.1909 - val_accuracy: 0.9381
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9374
# Epoch 3: val_accuracy did not improve from 0.93810
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1905 - accuracy: 0.9374 - val_loss: 0.1978 - val_accuracy: 0.9324
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9389
# Epoch 4: val_accuracy improved from 0.93810 to 0.94460, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1814 - accuracy: 0.9389 - val_loss: 0.1751 - val_accuracy: 0.9446
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9413
# Epoch 5: val_accuracy improved from 0.94460 to 0.94743, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1748 - accuracy: 0.9413 - val_loss: 0.1644 - val_accuracy: 0.9474
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9429
# Epoch 6: val_accuracy did not improve from 0.94743
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1723 - accuracy: 0.9429 - val_loss: 0.1626 - val_accuracy: 0.9463
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9447
# Epoch 7: val_accuracy did not improve from 0.94743
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1668 - accuracy: 0.9447 - val_loss: 0.1714 - val_accuracy: 0.9466
# Epoch 8/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9449
# Epoch 8: val_accuracy did not improve from 0.94743
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1639 - accuracy: 0.9449 - val_loss: 0.1621 - val_accuracy: 0.9452
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9463
# Epoch 9: val_accuracy did not improve from 0.94743
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1603 - accuracy: 0.9463 - val_loss: 0.1606 - val_accuracy: 0.9457
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9465
# Epoch 10: val_accuracy improved from 0.94743 to 0.94969, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1589 - accuracy: 0.9465 - val_loss: 0.1548 - val_accuracy: 0.9497
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9472
# Epoch 11: val_accuracy did not improve from 0.94969
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1548 - accuracy: 0.9472 - val_loss: 0.1562 - val_accuracy: 0.9494
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9488
# Epoch 12: val_accuracy improved from 0.94969 to 0.95308, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1506 - accuracy: 0.9488 - val_loss: 0.1492 - val_accuracy: 0.9531
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9485
# Epoch 13: val_accuracy did not improve from 0.95308
# ...
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9615
# Epoch 27: val_accuracy did not improve from 0.95478
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1067 - accuracy: 0.9615 - val_loss: 0.1400 - val_accuracy: 0.9534
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9606
# Epoch 28: val_accuracy did not improve from 0.95478
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1072 - accuracy: 0.9606 - val_loss: 0.1358 - val_accuracy: 0.9539
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9636
# Epoch 29: val_accuracy did not improve from 0.95478
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0994 - accuracy: 0.9636 - val_loss: 0.1553 - val_accuracy: 0.9497
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9634
# Epoch 30: val_accuracy did not improve from 0.95478
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1014 - accuracy: 0.9634 - val_loss: 0.1566 - val_accuracy: 0.9503
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9649
# Epoch 31: val_accuracy improved from 0.95478 to 0.95534, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0942 - accuracy: 0.9649 - val_loss: 0.1407 - val_accuracy: 0.9553
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9651
# Epoch 32: val_accuracy did not improve from 0.95534
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0920 - accuracy: 0.9651 - val_loss: 0.1388 - val_accuracy: 0.9531
# Epoch 33/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9682
# Epoch 33: val_accuracy improved from 0.95534 to 0.95619, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_5.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0874 - accuracy: 0.9682 - val_loss: 0.1439 - val_accuracy: 0.9562
# Epoch 34/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9690
# Epoch 34: val_accuracy did not improve from 0.95619
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0834 - accuracy: 0.9690 - val_loss: 0.1636 - val_accuracy: 0.9536
# Epoch 35/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9687
# Epoch 35: val_accuracy did not improve from 0.95619
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0827 - accuracy: 0.9687 - val_loss: 0.1411 - val_accuracy: 0.9520
# Epoch 36/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9732
# Epoch 36: val_accuracy did not improve from 0.95619
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0741 - accuracy: 0.9732 - val_loss: 0.1476 - val_accuracy: 0.9545
# Epoch 37/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9720
# Epoch 37: val_accuracy did not improve from 0.95619
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0758 - accuracy: 0.9720 - val_loss: 0.1457 - val_accuracy: 0.9505
# Epoch 38/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9723
# Epoch 38: val_accuracy did not improve from 0.95619
# Restoring model weights from the end of the best epoch: 28.
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0791 - accuracy: 0.9723 - val_loss: 0.1472 - val_accuracy: 0.9522
# Epoch 38: early stopping
# 166/166 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# Fold 6:
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 0.3171 - accuracy: 0.8769
# Epoch 1: val_accuracy improved from -inf to 0.93697, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 7s 18ms/step - loss: 0.3171 - accuracy: 0.8769 - val_loss: 0.1921 - val_accuracy: 0.9370
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9310
# Epoch 2: val_accuracy improved from 0.93697 to 0.94404, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.2108 - accuracy: 0.9310 - val_loss: 0.1703 - val_accuracy: 0.9440
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.9376
# Epoch 3: val_accuracy improved from 0.94404 to 0.95054, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1849 - accuracy: 0.9376 - val_loss: 0.1610 - val_accuracy: 0.9505
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9408
# Epoch 4: val_accuracy did not improve from 0.95054
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1758 - accuracy: 0.9408 - val_loss: 0.1604 - val_accuracy: 0.9480
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9418
# Epoch 5: val_accuracy did not improve from 0.95054
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1731 - accuracy: 0.9418 - val_loss: 0.1589 - val_accuracy: 0.9486
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9435
# Epoch 6: val_accuracy did not improve from 0.95054
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1685 - accuracy: 0.9435 - val_loss: 0.1557 - val_accuracy: 0.9500
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9443
# Epoch 7: val_accuracy did not improve from 0.95054
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1640 - accuracy: 0.9443 - val_loss: 0.1752 - val_accuracy: 0.9364
# Epoch 8/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9457
# Epoch 8: val_accuracy did not improve from 0.95054
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1615 - accuracy: 0.9457 - val_loss: 0.1592 - val_accuracy: 0.9466
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9461
# Epoch 9: val_accuracy did not improve from 0.95054
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1571 - accuracy: 0.9461 - val_loss: 0.1536 - val_accuracy: 0.9480
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9465
# Epoch 10: val_accuracy improved from 0.95054 to 0.95082, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1567 - accuracy: 0.9465 - val_loss: 0.1579 - val_accuracy: 0.9508
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9455
# Epoch 11: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1619 - accuracy: 0.9455 - val_loss: 0.1475 - val_accuracy: 0.9494
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9481
# Epoch 12: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1517 - accuracy: 0.9481 - val_loss: 0.1485 - val_accuracy: 0.9508
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9483
# Epoch 13: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1521 - accuracy: 0.9483 - val_loss: 0.1456 - val_accuracy: 0.9494
# Epoch 14/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9499
# Epoch 14: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1469 - accuracy: 0.9499 - val_loss: 0.1474 - val_accuracy: 0.9497
# Epoch 15/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9491
# Epoch 15: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1497 - accuracy: 0.9491 - val_loss: 0.1442 - val_accuracy: 0.9500
# Epoch 16/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9507
# Epoch 16: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1422 - accuracy: 0.9507 - val_loss: 0.1508 - val_accuracy: 0.9480
# Epoch 17/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9508
# Epoch 17: val_accuracy did not improve from 0.95082
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1424 - accuracy: 0.9508 - val_loss: 0.1567 - val_accuracy: 0.9474
# Epoch 18/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9520
# Epoch 18: val_accuracy improved from 0.95082 to 0.95223, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 17ms/step - loss: 0.1386 - accuracy: 0.9520 - val_loss: 0.1380 - val_accuracy: 0.9522
# Epoch 19/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9517
# Epoch 19: val_accuracy did not improve from 0.95223
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1366 - accuracy: 0.9517 - val_loss: 0.1462 - val_accuracy: 0.9494
# Epoch 20/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9537
# Epoch 20: val_accuracy did not improve from 0.95223
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1325 - accuracy: 0.9537 - val_loss: 0.1363 - val_accuracy: 0.9511
# Epoch 21/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9553
# Epoch 21: val_accuracy did not improve from 0.95223
# 277/277 [==============================] - 5s 17ms/step - loss: 0.1300 - accuracy: 0.9553 - val_loss: 0.1378 - val_accuracy: 0.9514
# Epoch 22/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9538
# Epoch 22: val_accuracy improved from 0.95223 to 0.95308, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1313 - accuracy: 0.9538 - val_loss: 0.1351 - val_accuracy: 0.9531
# Epoch 23/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9573
# Epoch 23: val_accuracy did not improve from 0.95308
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1229 - accuracy: 0.9573 - val_loss: 0.1397 - val_accuracy: 0.9511
# Epoch 24/100
# 276/277 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9568
# Epoch 24: val_accuracy improved from 0.95308 to 0.95478, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1212 - accuracy: 0.9568 - val_loss: 0.1375 - val_accuracy: 0.9548
# Epoch 25/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9586
# Epoch 25: val_accuracy did not improve from 0.95478
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1176 - accuracy: 0.9586 - val_loss: 0.1380 - val_accuracy: 0.9508
# Epoch 26/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9602
# Epoch 26: val_accuracy did not improve from 0.95478
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1164 - accuracy: 0.9602 - val_loss: 0.1346 - val_accuracy: 0.9531
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9587
# Epoch 27: val_accuracy improved from 0.95478 to 0.95845, saving model to /home/bilz/air/models/bd_MAGNet_V1_W_6_F_6.h5
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1174 - accuracy: 0.9587 - val_loss: 0.1275 - val_accuracy: 0.9585
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9606
# Epoch 28: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1114 - accuracy: 0.9606 - val_loss: 0.1327 - val_accuracy: 0.9545
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9611
# Epoch 29: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1101 - accuracy: 0.9611 - val_loss: 0.1284 - val_accuracy: 0.9551
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9608
# Epoch 30: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1111 - accuracy: 0.9608 - val_loss: 0.1347 - val_accuracy: 0.9534
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9612
# Epoch 31: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1082 - accuracy: 0.9612 - val_loss: 0.1236 - val_accuracy: 0.9551
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9646
# Epoch 32: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 17ms/step - loss: 0.1000 - accuracy: 0.9646 - val_loss: 0.1638 - val_accuracy: 0.9536
# Epoch 33/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9630
# Epoch 33: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.1028 - accuracy: 0.9630 - val_loss: 0.1273 - val_accuracy: 0.9556
# Epoch 34/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9637
# Epoch 34: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0977 - accuracy: 0.9637 - val_loss: 0.1342 - val_accuracy: 0.9505
# Epoch 35/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9655
# Epoch 35: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0934 - accuracy: 0.9655 - val_loss: 0.1279 - val_accuracy: 0.9531
# Epoch 36/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9647
# Epoch 36: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0998 - accuracy: 0.9647 - val_loss: 0.1248 - val_accuracy: 0.9534
# Epoch 37/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9665
# Epoch 37: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0892 - accuracy: 0.9665 - val_loss: 0.1339 - val_accuracy: 0.9508
# Epoch 38/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9690
# Epoch 38: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0850 - accuracy: 0.9690 - val_loss: 0.1328 - val_accuracy: 0.9565
# Epoch 39/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9695
# Epoch 39: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0810 - accuracy: 0.9695 - val_loss: 0.1443 - val_accuracy: 0.9534
# Epoch 40/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9704
# Epoch 40: val_accuracy did not improve from 0.95845
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0801 - accuracy: 0.9704 - val_loss: 0.1375 - val_accuracy: 0.9525
# Epoch 41/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9682
# Epoch 41: val_accuracy did not improve from 0.95845
# Restoring model weights from the end of the best epoch: 31.
# 277/277 [==============================] - 5s 16ms/step - loss: 0.0825 - accuracy: 0.9682 - val_loss: 0.1399 - val_accuracy: 0.9520
# Epoch 41: early stopping
# 166/166 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 11ms/step

# %% [markdown]
# ## Display the Results

# %%
print(f"Accuracy: {test_acc}")
print(f"F1-score: {test_f1}")
print(f"Mean Prediction Time (sec): {mean_prediction_time:.6f}")
print(f"Median Prediction Time (sec): {median_prediction_time:.6f}")
print(f"Mean Training Time (sec): {mean_training_time:.6f}")
print(f"Median Training Time (sec): {median_training_time:.6f}")
print(f"Mean Single Prediction Time (msec): {mean_prediction_time * 1000:.3f}")
print(f"Median Single Prediction Time (msec): {median_prediction_time * 1000:.3f}")
print(f"Mean Required Memory (Mb): {total_memory_mb:.4f}")
print(f"Median Required Memory (Mb): {total_memory_mb:.4f}")
print(f"Mean Model Parameters (K): {total_params_kb:.2f}")
print(f"Median Model Parameters (K): {total_params_kb:.2f}")
# Out:
# Accuracy: [0.9427279577995479, 0.9463074604370761, 0.9478146194423511, 0.947249434815373, 0.9483798040693293, 0.9470610399397137]
# F1-score: [0.9426986714423455, 0.9462516782804914, 0.9477734664035157, 0.9472049949792456, 0.9483177006310507, 0.9470192926331695]
# Mean Prediction Time (sec): 0.029731
# Median Prediction Time (sec): 0.029479
# Mean Training Time (sec): 170.696873
# Median Training Time (sec): 178.869220
# Mean Single Prediction Time (msec): 29.731
# Median Single Prediction Time (msec): 29.479
# Mean Required Memory (Mb): 0.2710
# Median Required Memory (Mb): 0.2710
# Mean Model Parameters (K): 69.38
# Median Model Parameters (K): 69.38

# %% [markdown]
# ## Confusion Matrix

# %%
# Function to draw the confusion matrix and ROC curve
def drawConfusionMatrix(myModel, X_test, y_test):
    class_labels = ['Outdoor', 'Indoor']
    # Measure the time it takes to predict a single sample
    start_time = time.time()
    predict_x = myModel.predict(X_test)
    end_time = time.time()

    # Calculate the prediction time
    prediction_time = end_time - start_time
    print('Prediction time:', prediction_time, 'seconds')

    y_pred = np.argmax(predict_x, axis=1)
    mat = confusion_matrix(y_test, y_pred)
    sns.heatmap(mat, xticklabels=class_labels, yticklabels=class_labels, annot=True, linewidths=0.1, fmt='d', cmap='YlGnBu')
    plt.title("Confusion matrix", fontsize=15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Calculate ROC curve and AUC
    y_prob = predict_x[:, 1]  # Probability for the positive class (Indoor)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=1)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Display confusion matrix and ROC curve
drawConfusionMatrix(trained_model, X_test, y_test)
# Out:
# 166/166 [==============================] - 1s 4ms/step
# Prediction time: 0.7850778102874756 seconds
